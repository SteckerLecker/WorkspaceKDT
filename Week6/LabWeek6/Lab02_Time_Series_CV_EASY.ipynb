# %% [markdown]
# # Lab 02: Time_Series_CV
#
# ## Goals
# Practice the concepts from Lecture 02 with hands-on exercises.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import *
from sklearn.datasets import *
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import *
import warnings
warnings.filterwarnings('ignore')
np.random.seed(42)
print('✓ Ready!')

# %% [markdown]
# ## Exercise 1: Basic Implementation
#
# **TODO:** Implement the main technique from Lecture 02

# %%
# Your code here

# %% [markdown]
# ## Exercise 2: Compare Strategies
#
# **TODO:** Compare different approaches and analyze results

# %%
# Your code here

# %% [markdown]
# ## Exercise 3: Apply to Real Data
#
# **TODO:** Use a real dataset and implement properly

# %%
# Your code here

# %% [markdown]
# ## Challenge: Advanced Application
#
# **TODO:** Combine multiple techniques from this week

# %%
# Your code here

# %% [markdown]
# ## Summary
#
# What did you learn from this lab?
#
# **Key Takeaways:**
# 1.
# 2.
# 3.
